# %% [markdown]
# # Init

# %%
# scripts/run_workspace.py
import time
from pathlib import Path
from workspace import Workspace
from workspace.recipes.change_tool import ChangeTool


ws = Workspace(config_path="config.yaml.j2")
core = ws.components["core"]
core.simulation(True)

tool_rack_1 = ws.components["tool_rack_1"]
change_tool_1 = ChangeTool(workspace=ws, core=core, tool_rack=tool_rack_1, speed_factor=2,left_approach=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       4 from workspace import Workspace
#       5 from workspace.recipes.change_tool import ChangeTool
# ----> 8 ws = Workspace(config_path="config.yaml.j2")
#       9 core = ws.components["core"]
#      10 core.simulation(True)
#
# File ~/Downloads/workspace/workspace/workspace/workspace.py:28, in Workspace.__init__(self, config_path)
#      26 self.components = {}
#      27 for name, ccfg in comp_cfgs.items():
# ---> 28     self.components[name] = comp_factory.create_component(name, ccfg, self)
#      30 # 2) perform attachments (child-side offset)
#      31 for child_name, ccfg in comp_cfgs.items():
#
# File ~/Downloads/workspace/workspace/workspace/components/factory.py:37, in create_component(name, cfg, workspace)
#      35 cls = _registry.get(type_name)
#      36 if cls is None:
# ---> 37     raise ValueError(f"Unknown component type '{type_name}' for '{name}'")
#      39 return cls(name, cfg, workspace)
#
# ValueError: Unknown component type 'body_autosampler_2ml' for 'body_A1'

# %% [markdown]
# # Tool

# %%
change_tool_1.pick_tool()
# change_tool_1.place_tool()
# Out:
# No tool to pick, aborting
# False

# %% [markdown]
# # Plate

# %%
from workspace.recipes.plate import Plate

plate_1 = Plate(workspace=ws, core=core, container=ws.components["microplate_1"], speed_factor=0.1,base_distance=250)

# %%
for r in "B":
    for c in range(2,3):
        index = f"{r}{c}"
        plate_1.pick_from(index)
        #plate_2.place_in(index)

# %% [markdown]
# # Decapper

# %%
from workspace.recipes.decapper import Decapper
decapper_1 = Decapper(workspace=ws, core=core, container=ws.components["microplate_1"], speed_factor=0.5,base_distance=250)
