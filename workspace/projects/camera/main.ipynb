# %% [markdown]
# # Init

# %%
# scripts/run_workspace.py
import time
from pathlib import Path
from workspace import Workspace
from workspace.recipes.change_tool import ChangeTool


ws = Workspace(config_path="config.yaml.j2")
core = ws.components["core"]
core.simulation(True)

tool_rack_1 = ws.components["tool_rack_1"]
change_tool_1 = ChangeTool(workspace=ws, core=core, tool_rack=tool_rack_1, speed_factor=2,left_approach=True)
# Out:
# [Display] socket.io connected
# [Display] sending initial snapshot (34 items)
# [Display] Running at 60 fps

# %% [markdown]
# # Tool

# %%
change_tool_1.pick_tool()
# change_tool_1.place_tool()
# Out:
# True

# %% [markdown]
# # Adapter

# %%
from workspace.recipes.handle_adapter import HandleAdapter

holder_1 = HandleAdapter(workspace=ws, core=core, container=ws.components["sbs_adapter_1"], speed_factor=0.5,left_approach=True, ref_joints=[-90, 90, -90, 90, 0, 0, 0, 0])
holder_2 = HandleAdapter(workspace=ws, core=core, container=ws.components["sbs_adapter_2"], speed_factor=0.5,left_approach=True, ref_joints=[-90, 90, -90, 90, 0, 0, 0, 0])

# %%
holder_1.pick_from("front")
#holder_2.place_in()
# Out:
# True

# %% [markdown]
# # Hotel

# %%
from workspace.recipes.hotel import Hotel

hotel_1 = Hotel(workspace=ws, core=core, container=ws.components["hotel_1"], speed_factor=0.1,left_approach=True, base_distance=350, rail_step=10, rail_span=20)
hotel_2 = Hotel(workspace=ws, core=core, container=ws.components["hotel_2"], speed_factor=0.1,left_approach=True, base_distance=350, rail_step=10, rail_span=20)
hotel_3 = Hotel(workspace=ws, core=core, container=ws.components["hotel_3"], speed_factor=0.1,left_approach=True, base_distance=350, rail_step=10, rail_span=20)
hotel_4 = Hotel(workspace=ws, core=core, container=ws.components["hotel_4"], speed_factor=0.1,left_approach=True, base_distance=350, rail_step=10, rail_span=20)
hotel_5 = Hotel(workspace=ws, core=core, container=ws.components["hotel_5"], speed_factor=0.1,left_approach=True, base_distance=350, rail_step=10, rail_span=20)
hotel_6 = Hotel(workspace=ws, core=core, container=ws.components["hotel_6"], speed_factor=0.1,left_approach=True, base_distance=350, rail_step=10, rail_span=20)
hotel_7 = Hotel(workspace=ws, core=core, container=ws.components["hotel_7"], speed_factor=0.1,left_approach=True, base_distance=350, rail_step=10, rail_span=20)
hotel_8 = Hotel(workspace=ws, core=core, container=ws.components["hotel_8"], speed_factor=0.1,left_approach=True, base_distance=350, rail_step=10, rail_span=20)

# %%
for i in range(1, 4):
    hotel_1.place_in(i)
    hotel_1.pick_from(i)

for i in range(1, 4):
    hotel_5.place_in(i)
    hotel_5.pick_from(i)

for i in range(1, 4):
    hotel_2.place_in(i)
    hotel_2.pick_from(i)

for i in range(1, 4):
    hotel_6.place_in(i)
    hotel_6.pick_from(i)

for i in range(1, 4):
    hotel_3.place_in(i)
    hotel_3.pick_from(i)

for i in range(1, 4):
    hotel_7.place_in(i)
    hotel_7.pick_from(i)


for i in range(1, 4):
    hotel_4.place_in(i)
    hotel_4.pick_from(i)

for i in range(1, 4):
    hotel_8.place_in(i)
    hotel_8.pick_from(i)
