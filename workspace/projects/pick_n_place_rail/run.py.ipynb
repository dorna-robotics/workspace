# %%
# scripts/run_workspace.py
import time
from pathlib import Path
from workspace import Workspace
from workspace.recipes.change_tool import ChangeTool
from workspace.recipes.handle_microtube import HandleMicrotube


ws = Workspace(config_path="config.yaml")
core = ws.components["core"]
core.simulation(True)

tool_rack_1 = ws.components["tool_rack_1"]
tool_rack_2 = ws.components["tool_rack_2"]

microplate_1 = ws.components["microplate_1"]
microplate_2 = ws.components["microplate_2"]
change_tool_1 = ChangeTool(workspace=ws, core=core, tool_rack=tool_rack_1, speed_factor=2,left_approach=False)
change_tool_2 = ChangeTool(workspace=ws, core=core, tool_rack=tool_rack_2, speed_factor=2,left_approach=True,base_distance=150)
handle_microtube_1 = HandleMicrotube(workspace=ws, core=core, microplate=microplate_1, speed_factor=2,left_approach=False)
handle_microtube_2 = HandleMicrotube(workspace=ws, core=core, microplate=microplate_2, speed_factor=2,left_approach=False)

# %%
change_tool_1.pick_tool()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 change_tool_1.pick_tool()
#
# File D:\project_workspace\workspace\workspace\workspace\recipes\change_tool.py:68, in ChangeTool.pick_tool(self)
#      64 J,C = self.core.IK(target_solid=self.tool_rack.assembly["tool_rack"], target_anchor="tool_connection", target_offset=[0,0,-self.retract_height_without_tool,0,0,0], tool_solid=self.core.toolchanger_robot_side, tool_anchor="toolchanger_connection", tool_offset=[0,0,0,0,0,0],base_distance=self.base_distance,
#      65 rail_step=self.rail_step, rail_span=self.rail_span, left_approach=self.left_approach,ref_joints=self.ref_joints)
#      67 if C == 2:
# ---> 68     self.core.robot_api.jmove(J, vel=200*self.speed_factor,accel=5000*self.speed_factor,jerk=50000*self.speed_factor)
#      69 else:
#      70     print("Could not find a valid approach pose to the tool")
#
# File D:\project_workspace\workspace\workspace\workspace\components\core.py:738, in SimulationAPI.jmove(self, joint, vel, accel, jerk)
#     736     sleep_for = next_tick_time - time.perf_counter()
#     737     if sleep_for > 0:
# --> 738         time.sleep(sleep_for)
#     740 self.joints = tgt[:]
#     742 return 2
#
# KeyboardInterrupt:

# %%
handle_microtube_1.pick_tube(index="A11")
handle_microtube_2.place_tube(index="A11")
# Out:
# True

# %%
change_tool_2.place_tool()
# Out:
# True

# %%
from workspace.components.calibration import Calibration
calib = Calibration("arm_calibration.cfg")

# %%
calib.add_point("robot_arm", [0, 20, 20, 32, 40, 50], [0.1, 20.1, 19.8, 32.4, 39.9, 50.3])
calib.add_point("robot_arm", [0, 22, 20, 32, 48, 50], [0.1, 22.4, 19.8, 32.4, 48.1, 50.3])

# %%
corrected = calib.interpolate_corrected("robot_arm", [0, 20, 20, 32, 40, 50])
print("Corrected values:", corrected)
# Out:
# Corrected values: [0.1, 20.1, 19.8, 32.4, 39.9, 50.3]

# %%
calib.clear_all()
