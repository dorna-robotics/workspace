# %% [markdown]
# # imports

# %%
import time
from dorna2 import Dorna

# %%
robot = Dorna()
robot.connect("192.168.254.88")
# Out:
# True

# %%
# motor
robot.set_motor(1)

# sleep
time.sleep(1)

# home rail
#robot.home_with_stop(index=6, val=-15.9, dir=-1)

# home feeder
robot.home_with_encoder_index(index=7, val=62.37)
# Out:
# 2.0

# %%
robot.close()
# Out:
# True
