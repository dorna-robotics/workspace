# %% [markdown]
# # vertical calibration

# %% [markdown]
# ## init

# %%
# scripts/run_workspace.py
from workspace import Workspace
from util import create_recipes

# workspace
workspace = Workspace(config_path=["config/base.j2", "config/clb_tool_rack.j2"])
# core
core = workspace.components["core"]
# recipes
rcp = create_recipes(workspace, core)
# Out:
# ✅ robot connected
# 🔵 simulation api enabled
# [Display] socket.io connected
# [Display] sending initial snapshot (25 items)
# [Display] Running at 60 fps

# %%
# pick tool
rcp["tool_rack_0"].pick()
# Out:
# True

# %%
core.simulation(False)
# Out:
# Switched to real robot API

# %% [markdown]
# ## calibrate

# %%
#rcp["tool_rack_0"].calibrate()
#rcp["tool_rack_1"].calibrate()
#rcp["tool_rack_2"].calibrate()
rcp["cap_holder"].calibrate()
#rcp["sbs_plate"].calibrate()
#rcp["decapper"].calibrate()
#rcp["feeder"].calibrate()
# Out:
# raw values: [-118.95204276570956, -17.558580423052433, -92.70885519587216, 0.0, 20.26743561892463, -118.95204276570956, 202.0, -112.86]
# corrected values: [-118.586426, -17.709961, -95.053711, 2.263184, 22.214355, -120.102539, 201.95625, -112.86]
# raw values: [-108.93105902765268, -17.22770263313498, -53.62858308814816, 0.0, -19.143714278716857, -18.93105902765268, 202.0, -112.86]
# corrected values: [-108.786621, -17.53418, -54.294434, -0.461426, -18.896484, -17.314453, 201.99375, -112.86]
# raw values: [-108.93105902765268, -17.227702633134925, -53.62858308814822, 0.0, -19.143714278716857, -108.93105902765268, 273.0, -112.86]
# corrected values: [-108.742676, -17.314453, -54.294434, -1.230469, -18.984375, -106.721191, 273.01875, -112.86]
# raw values: [-118.95204276570956, -17.558580423052433, -92.70885519587216, 0.0, 20.26743561892463, -28.952042765709507, 273.0, -112.86]
# corrected values: [-118.762207, -17.819824, -94.438477, 0.791016, 22.192383, -28.45459, 272.9625, -112.86]
