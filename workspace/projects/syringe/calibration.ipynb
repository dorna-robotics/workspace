# %% [markdown]
# # vertical calibration

# %% [markdown]
# ## init

# %%
# scripts/run_workspace.py
from workspace import Workspace
from util import create_recipes

# workspace
workspace = Workspace(config_path=["config/base.j2", "config/clb_tool_rack.j2"])
# core
core = workspace.components["core"]
# recipes
rcp = create_recipes(workspace, core)
# Out:
# ✅ robot connected
# 🔵 simulation api enabled
# [Display] socket.io connected
# [Display] sending initial snapshot (25 items)
# [Display] Running at 60 fps

# %%
# pick tool
rcp["tool_rack_0"].pick()
# Out:
# True

# %%
core.simulation(False)
# Out:
# Switched to real robot API

# %% [markdown]
# ## calibrate

# %%
#rcp["tool_rack_0"].calibrate()
#rcp["tool_rack_1"].calibrate()
#rcp["tool_rack_2"].calibrate()
rcp["cap_holder"].calibrate()
#rcp["sbs_plate"].calibrate()
#rcp["decapper"].calibrate()
#rcp["feeder"].calibrate()
# Out:
# raw values: [-118.95204276570956, -17.558580423052433, -92.70885519587216, 0.0, 20.26743561892463, -118.95204276570956, 202.0, -113.49]
# corrected values: [-118.740234, -17.995605, -92.966309, 0.307617, 21.09375, -118.410645, 202.0125, -113.49]
# raw values: [-108.93105910625468, -17.227702671411123, -53.6285829160949, 0.0, -19.143714412493978, -18.931059106254622, 202.0, -113.49]
# corrected values: [-108.808594, -17.687988, -53.261719, -0.593262, -19.072266, -17.731934, 202.0875, -113.49]
# raw values: [-108.93105902765268, -17.227702633134925, -53.62858308814822, 0.0, -19.143714278716857, -108.93105902765268, 273.0, -113.49]
# corrected values: [-108.786621, -17.666016, -53.4375, -0.637207, -18.830566, -107.62207, 272.94375, -113.49]
# raw values: [-118.95204276570956, -17.558580423052433, -92.70885519587216, 0.0, 20.267435618924623, -28.952042765709507, 273.0, -113.49]
# corrected values: [-118.54248, -17.95166, -92.900391, 0.175781, 21.115723, -27.971191, 272.8875, -113.49]

# %%
rcp["sbs_plate"].ref_joints
# Out:
# [-92.54991118361596,
#  -14.425671235060918,
#  -78.91852735452613,
#  0.0,
#  3.3441985895870268,
#  -2.5499111836159614,
#  362.5,
#  0]
