# %%
from main import main

# create workspace and start the thread
workspace = main()
# start workflow
workspace.rt.start()
# Out:
# ❌ core connection failed @ 192.168.137.100
# 🔵 core simulation api enabled
# ✅ printer connected @ 192.168.137.102
# ❌ pipettor connection failed @ /dev/ttyUSB0
# [Display] connect failed, retrying in 2s: Connection error
# [Display] Running at 60 fps
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 4
#       1 from main import main
#       3 # create workspace and start the thread
# ----> 4 workspace = main()
#       5 # start workflow
#       6 workspace.rt.start()
#
# File ~/Downloads/workspace/workspace/projects/printer/main.py:8, in main()
#       6 ws = Workspace(config_path=["config/base.j2", "config/layout.j2"])
#       7 rt_server = RuntimeServer(runtime=ws.rt, workflow_fn=workflow_fn, port=8000)
# ----> 8 rt_server.run()
#
# File ~/Downloads/workspace/workspace/workspace/runtime_server.py:89, in RuntimeServer.run(self)
# ...

# %%
from workspace import runtime_server
